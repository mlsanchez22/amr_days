# %%
#!pip install --upgrade google-cloud-bigquery pandas-gbq pyarrow

# %%
import sys
# !{sys.executable} -m pip install --upgrade google-cloud-bigquery pandas-gbq pyarrow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 261 kB 1.7 MB/s
# ...
#      |████████████████████████████████| 48 kB 6.9 MB/s
# ...
#      |████████████████████████████████| 154 kB 73.9 MB/s
# ...
#   Attempting uninstall: google-cloud-bigquery
#     Found existing installation: google-cloud-bigquery 3.38.0
#     Uninstalling google-cloud-bigquery-3.38.0:
#       Successfully uninstalled google-cloud-bigquery-3.38.0
#   Attempting uninstall: pandas-gbq
#     Found existing installation: pandas-gbq 0.30.0
#     Uninstalling pandas-gbq-0.30.0:
#       Successfully uninstalled pandas-gbq-0.30.0
# ...

# %%
from google.cloud import bigquery
import google.auth

# %%
# (opcional) ver quién está autenticado vía ADC
creds, proj = google.auth.default()
print("ADC project:", proj)
print(getattr(creds, "service_account_email", "User creds (no service_account_email)"))

client = bigquery.Client(project="mimic-pruebas")  # tu proyecto de cuota

query = """
SELECT COUNT(*) AS pacientes
FROM `physionet-data.mimiciv_v3_1_hosp.patients`
"""
df = client.query(query).to_dataframe()
print(df)
# Out:
# ADC project: None
# User creds (no service_account_email)
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# Cell In[4], line 12
#       6 client = bigquery.Client(project="mimic-pruebas")  # tu proyecto de cuota
#       8 query = """
#       9 SELECT COUNT(*) AS pacientes
#      10 FROM `physionet-data.mimiciv_v3_1_hosp.patients`
#      11 """
# ---> 12 df = client.query(query).to_dataframe()
#      13 print(df)
#
# File ~/.local/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py:2159, in QueryJob.to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, max_results, geography_as_object, bool_dtype, int_dtype, float_dtype, string_dtype, date_dtype, datetime_dtype, time_dtype, timestamp_dtype, range_date_dtype, range_datetime_dtype, range_timestamp_dtype)
#    1929 def to_dataframe(
#    1930     self,
# ...

# %%
import os
from google.cloud import bigquery   

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/home/m.lopez/Desktop/mimic-pruebas-1f20ed4c20d1.json"

# %%
# Nombre de tu proyecto en Google Cloud
PROJECT_ID = "mimic-pruebas"

# Crear cliente BigQuery
client = bigquery.Client(project=PROJECT_ID)

# Query de prueba
query = """
SELECT COUNT(*) AS pacientes
FROM `physionet-data.mimiciv_v3_1_hosp.patients`
"""

df = client.query(query).to_dataframe()
print(df)

# %%
from google.cloud import bigquery

# Crea el cliente usando tus credenciales ADC
client = bigquery.Client(project="mimic-pruebas")

# Consulta de prueba al dataset MIMIC-IV
query = """
SELECT COUNT(*) AS pacientes
FROM `physionet-data.mimiciv_v3_1_hosp.patients`
"""

df = client.query(query).to_dataframe()
print(df)

# %%
from google.cloud import bigquery
client = bigquery.Client(project="mimic-pruebas")

query = "SELECT COUNT(*) AS pacientes FROM `physionet-data.mimiciv_v3_1_hosp.patients`"
df = client.query(query).to_dataframe()
df.head()

# %%
from google.cloud import bigquery
client = bigquery.Client(project="mimic-pruebas")

query = "SELECT COUNT(*) AS pacientes FROM `physionet-data.mimiciv_v3_1_hosp.patients`"
df = client.query(query).to_dataframe()
df.head()

# %%
from pandas_gbq import read_gbq   # ejecuta SQL en BigQuery y devuelve un DataFrame
import pandas as pd              # manejo de dataframes
import numpy as np               # utilidades numéricas
import matplotlib.pyplot as plt  # gráficos base
import seaborn as sns            # gráficos de alto nivel (opcional)
